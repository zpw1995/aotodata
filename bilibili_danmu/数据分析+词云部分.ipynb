# %% [markdown]
# 朱小五：某互联网公司数据分析师，热衷于爬虫，数据分析，可视化，个人公众号《凹凸玩数据》

# %%
import pandas as pd
data =pd.read_csv('bili_ai5.csv',header=0,encoding="utf-8-sig") 
print(data.shape[0]) #数量
data.head(20)
# Out:
# 1000
#     Unnamed: 0                 comments
# 0            0                   看上去不错啊
# 1            1  嫌尴尬可以不看啊，为什么继续看，让自己更尴尬？
# 2            2                    本来就垃圾
# 3            3                       期待
# 4            4           这个是个日本演员......
# 5            5                    诺澜！！！
# 6            6                    预告片满分
# 7            7                 Hail海澜之家
# 8            8                  那诺澜怎么办？
# 9            9                     汉化公寓
# 10          10                      大三了
# 11          11                      八戒！
# 12          12                  是不是说。。。
# 13          13                  我觉得还可以啊
# 14          14                   五年级到大二
# 15          15                      挺好的
# 16          16                      高一了
# 17          17                      博三了
# 18          18                高一到大学毕业四年
# 19          19            曾小贤都变客串了，有P的料

# %%
#学生阶段在弹幕中的提及数
a = {'小学':'小学|一年级|二年级|三年级|四年级|五年级|六年级', 
     '初中':'初中|初一|初二|初三', 
     '高一':'高一', 
     '高二':'高二',
     '高三':'高三', 
     '大一':'大一', 
     '大二':'大二', 
     '大三':'大三', 
     '大四':'大四',}
for key, value in a.items():
    data[key] = data['comments'].str.contains(value)
staff_count = pd.Series({key: data.loc[data[key], 'comments'].count() for key in a.keys()}).sort_values()
print(staff_count)
# Out:
# 大四    12
# 高二    13
# 大三    18
# 高一    19
# 小学    23
# 初中    23
# 高三    24
# 大二    32
# 大一    43
# dtype: int64

# %%
import jieba
from collections import Counter
from pyecharts import WordCloud

stop_words = [x.strip() for x in open ('stopwords.txt',encoding="utf-8") ]
text = ''.join(data['comments'])
words = list(jieba.cut(text))
ex_sw_words = []
for word in words:
    if len(word)>1 and (word not in stop_words):
        ex_sw_words.append(word)
c = Counter()
c = Counter(ex_sw_words)
wc_data = pd.DataFrame({'word':list(c.keys()), 'counts':list(c.values())}).sort_values(by='counts', ascending=False).head(100)
wordcloud = WordCloud(width=1300, height=620)
wordcloud.add("", wc_data['word'], wc_data['counts'], word_size_range=[15, 80])
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min', 'wordcloud': '/nbextensions/echarts/echarts-wordcloud.min'
#         }
#     });
# </script>
#     <div id="ef2142af6a294370b6ad0fc08869c9a5" style="width:1300px;height:620px;"></div>
#
#
# <script>
#     require(['echarts', 'wordcloud'], function(echarts) {
#
# var myChart_ef2142af6a294370b6ad0fc08869c9a5 = echarts.init(document.getElementById('ef2142af6a294370b6ad0fc08869c9a5'), 'light', {renderer: 'canvas'});
#
# var option_ef2142af6a294370b6ad0fc08869c9a5 = {
#     "title": [
#         {
#             "left": "auto",
#             "top": "auto",
#             "textStyle": {
#                 "fontSize": 18
#             },
#             "subtextStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "toolbox": {
#         "show": true,
#         "orient": "vertical",
#         "left": "95%",
#         "top": "center",
#         "feature": {
#             "saveAsImage": {
#                 "show": true,
#                 "title": "save as image"
#             },
#             "restore": {
#                 "show": true,
#                 "title": "restore"
#             },
#             "dataView": {
#                 "show": true,
#                 "title": "data view"
#             }
#         }
#     },
#     "series_id": 5620003,
#     "tooltip": {
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "backgroundColor": "rgba(50,50,50,0.7)",
#         "borderColor": "#333",
#         "borderWidth": 0
#     },
#     "series": [
#         {
#             "type": "wordCloud",
#             "shape": "circle",
#             "rotationRange": [
#                 -90,
#                 90
#             ],
#             "rotationStep": 45,
#             "girdSize": 20,
#             "sizeRange": [
#                 15,
#                 80
#             ],
#             "data": [
#                 {
#                     "name": "\u554a\u554a\u554a",
#                     "value": 77,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(30,76,147)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u54c8\u54c8\u54c8",
#                     "value": 55,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(121,151,104)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u5927\u4e8c",
#                     "value": 31,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(59,68,12)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u54c8\u54c8\u54c8\u54c8",
#                     "value": 25,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(84,86,11)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u9ad8\u4e09",
#                     "value": 23,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(115,135,122)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u5367\u69fd",
#                     "value": 22,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(15,125,157)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u5c34\u5c2c",
#                     "value": 20,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(37,44,130)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u7fbd\u58a8",
#                     "value": 20,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(133,106,147)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u9ad8\u4e00",
#                     "value": 19,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(54,70,45)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u6284\u88ad",
#                     "value": 19,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(113,100,156)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u5927\u4e09",
#                     "value": 18,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(130,11,34)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u771f\u7684",
#                     "value": 17,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(36,99,45)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u5de5\u4f5c",
#                     "value": 17,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(149,154,46)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u5c0f\u5b66",
#                     "value": 16,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(50,58,12)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u5927\u4e00",
#                     "value": 15,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(58,71,5)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u5927\u70ae",
#                     "value": 14,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(106,112,56)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u5f20\u4f1f",
#                     "value": 12,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(24,114,60)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u5927\u56db",
#                     "value": 12,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(29,49,60)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u5b98\u65b9",
#                     "value": 12,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(104,2,31)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u5e08\u5144",
#                     "value": 12,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(48,142,14)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u8bfa\u6f9c",
#                     "value": 11,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(78,105,51)"
#                         }
